# %%
import pandas as pd

mkmusic_df = pd.read_csv('billboard200.csv')
display(mkmusic_df)
# Out:
# C:\Users\maced\AppData\Local\Temp\ipykernel_5996\3955591246.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   mkmusic_df = pd.read_csv('billboard200.csv')
#               Date                                         Song  \
# 0       1963-08-14                       Days Of Wine And Roses
# 1       1963-08-14  Little Stevie Wonder/The 12 Year Old Genius
# 2       1963-08-14                              West Side Story
# 3       1963-08-14                                     (Moving)
# 4       1963-08-14                          Trini Lopez At PJ's
# ...            ...                                          ...
# 623252  2024-03-27                 Stars: The Best Of 1992-2002
# 623253  2024-03-27                                  Pray 4 Love
# 623254  2024-03-27                           Boys Of Faith (EP)
# 623255  2024-03-27                            House Of Balloons
# ...

# %%
mkmusic_df = mkmusic_df[["Rank","Song", "Artist", "Peak Position","Weeks in Charts"]]
top_faixa = mkmusic_df.sort_values('Weeks in Charts', ascending= False)
display(top_faixa [:100])
# Out:
#         Rank                Song           Artist  Peak Position  \
# 410599   143         Josh Groban      Josh Groban              8
# 532378   122       Greatest Hits     Foo Fighters             11
# 301395   139    Luck Of The Draw     Bonnie Raitt              2
# 104506   116       Summer Breeze   Seals & Crofts              7
# 607808   152      Channel Orange      Frank Ocean              2
# ...      ...                 ...              ...            ...
# 566537    81             Starboy       The Weeknd              1
# 541148    92  In The Lonely Hour        Sam Smith              2
# 160759   169  The Grand Illusion             Styx              6
# 455896    40                  15       Buckcherry             39
# 197125   127        Off The Wall  Michael Jackson              3
#
#        Weeks in Charts
# 410599              99
# 532378              99
# 301395              99
# 104506              99
# 607808              99
# ...                ...
# ...
